# %% [markdown]
# # Comments

# %% [markdown]
# - single line comment
# - multi line comment

# %%
Name = 'Mohan' # name of candidate
Name
# Out:
# 'Mohan'

# %%
""" This 
is
a
multiline comment
for practice """
10+10
# Out:
# 20

# %%
# This 
# is
# a
# multiline 
# comment

# %%
# This 
# is
# a
# multiline comment

# %% [markdown]
# - ctrl +/ gives sinle line comment for all lines

# %% [markdown]
# # Statements

# %% [markdown]
# - instruction that a python interpreter can execuit

# %%
p1 = 20 + 30 + 40 + 50 + 60 
p1
# Out:
# 200

# %%
p1 = 20 + 30 \
+ 40 + 50 \
+ 60 
p1
# Out:
# 200

# %% [markdown]
# # Data Types

# %%
# Data types

# %% [markdown]
# - 1.Numbers
# - 2.Boolean
# - 3.Set
# - 4.Dictionary(Mapping)
# - 5.Sequential

# %%
import sys

# %% [markdown]
# ### 1. Numbers

# %%
# integer: denoted as int 
# Float: deloted as float
# Complex:deloted as Complex

# %%
# Integers
xy = 50
print(xy)
type(xy)
# Out:
# 50
# int

# %%
ab = -20
print(ab)
type(ab)
# Out:
# -20
# int

# %%
# Float

# %%
ab = 3.5
print(ab)
type(ab)
# Out:
# 3.5
# float

# %%
# Complex

# %%
ab = 5+8j
print(ab)
type(ab)
# Out:
# (5+8j)
# complex

# %%
ab = 5+j8
print(ab)
type(ab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 ab = 5+j8
#       2 print(ab)
#       3 type(ab)
#
# NameError: name 'j8' is not defined

# %%
j = 5-8j
print(j)
type(j)
# Out:
# (5-8j)
# complex

# %%
m = 1+8j
print(m)
type(m)
# Out:
# (1+8j)
# complex

# %%
m =2*8j
print(m)
type(m)
# Out:
# 16j
# complex

# %%
a=15
b=25
c=a+b

# %%
print(c)
# Out:
# 40

# %% [markdown]
# # Boolean

# %%
# Boolean datatypes can have only two possible values: TRUE or FALSE

# %%
a = True
type(a)
# Out:
# bool

# %%
b = False
type(b)
# Out:
# bool

# %%
bool 1 = true # variable does not conatin a spaces
# Out:
#   Cell In[51], line 1
#     bool 1 = true # variable does not conatin a spaces
#          ^
# SyntaxError: invalid syntax

# %%
bool1 = True

# %%
bool1
# Out:
# True

# %%
print (bool(0))
# Out:
# False

# %% [markdown]
# - In boolean only 0 is False except 0 any number will be True

# %%
print(bool(1))
# Out:
# True

# %%
print(bool(3+6j))
# Out:
# True

# %% [markdown]
# # String

# %% [markdown]
# - A sequence of characters is a string

# %%
a = "Hello Mohan"
print(a)
type(a)
# Out:
# Hello Mohan
# str

# %%
address = "7-65 kosara street kumili"
print(address)
type(address)
# Out:
# 7-65 kosara street kumili
# str

# %% [markdown]
# # String Indexing

# %%
str1 = "Hello Mohan"

# %%
str1
# Out:
# 'Hello Mohan'

# %%
str1[0]
# Out:
# 'H'

# %%
str1[6]
# Out:
# 'M'

# %%
str1[2]
# Out:
# 'l'

# %%
str1[9]
# Out:
# 'a'

# %%
str1[0:6]
# Out:
# 'Hello '

# %%
str1[6:11]
# Out:
# 'Mohan'

# %%
str1[-4]
# Out:
# 'o'

# %%
str2 = "Python Programming"

# %%
str2
# Out:
# 'Python Programming'

# %%
str2[3]
# Out:
# 'h'

# %%
str2[10]
# Out:
# 'g'

# %%
str2[14]
# Out:
# 'm'

# %%
str2[-15]
# Out:
# 'h'

# %%
str2[-8]
# Out:
# 'g'

# %%
str2[-4]
# Out:
# 'm'
