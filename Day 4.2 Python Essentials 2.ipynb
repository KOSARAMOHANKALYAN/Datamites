# %% [markdown]
# # Python Operators

# %% [markdown]
# - operators are special symbols in python which are used to perform computations or certain checks on variables/values.

# %% [markdown]
# # Arthimatic operations

# %%
5+6
# Out:
# 11

# %%
a1 = 5
a2 = 3
a3 = 10
a4 = 5
a5 = 7

# %%
a1+a2 # addition
# Out:
# 8

# %%
a1+a2+a3+a4+a5
# Out:
# 30

# %%
a1-a2 # subraction
# Out:
# 2

# %%
a1*a2 # multiplication
# Out:
# 15

# %%
a1/a2 # division
# Out:
# 1.6666666666666667

# %%
a3//a5 # floor division
# Out:
# 1

# %%
# modulo operator refers to the remainder after division
10%3 # modulus
# Out:
# 1

# %%
15%4
# Out:
# 3

# %%
x='Data'
y='Science'
z=x + y
print(z)
# Out:
# DataScience

# %%
x='Data'
y='Science'
z=x + " "+ y
print(z)
# Out:
# Data Science

# %%
# difference  b/w division and floor division interview question

# %%
2**4
# Out:
# 16

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
0/1
# Out:
# 0.0

# %% [markdown]
# # Comparison operator

# %%
# Comparison returns a boolean value on evaluation

# %%
"Hi" == "hi" # equal
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
"Hi" != "hi" # not equal
# Out:
# True

# %%
10>3
# Out:
# True

# %%
10<3
# Out:
# False

# %%
10>=3
# Out:
# True

# %%
10<=3
# Out:
# False

# %% [markdown]
# # Logical operator

# %%
# The key logical operators are and, or & not 
T = True and True
F = False and True
F = False and False
F = True and False

# %%
a1 = True
a2 = False
b1 = True
b2 = False

# %%
a1 and b1 # both condections are true
# Out:
# True

# %%
a2 and b2 #
# Out:
# False

# %%
a1 and b2
# Out:
# False

# %%
a2 and b1
# Out:
# False

# %%
# any one true means all true 
    # T = True and True
    # T = False and True
    # F = False and False
    # T = True and False
a1 or b1
# Out:
# True

# %%
a2 or b2
# Out:
# False

# %%
a1 & b1
# Out:
# True

# %%
not a1 # false if operand is True and vice versa
# Out:
# False

# %%
not a2
# Out:
# True

# %% [markdown]
# # Membership operator

# %%
a = "Hello Everyone"

# %%
"e" in a
# Out:
# True

# %%
"e" not in a
# Out:
# False

# %%
"x" in a
# Out:
# False

# %%
"x" not in a
# Out:
# True

# %% [markdown]
# # Conditional statements

# %% [markdown]
# - if
# - elif
# - else

# %% [markdown]
# - The if statement evaluate an expression and excutes a block of code on the condition that the expression is true.
# - In case the expression returns a False, the if block-of-code is ignored
