# %% [markdown]
# # List Functions

# %% [markdown]
# * Addition
#     * append
#     * Extend
#     * Insert

# %% [markdown]
# * Removing
#     * pop
#     * Remove
#     * clear

# %%
l1=['abc',123,True]
l1
# Out:
# ['abc', 123, True]

# %%
# append
l1.append(100.191)

# %%
l1
# Out:
# ['abc', 123, True, 100.191]

# %%
# Insert
l1.insert(1, 'hello')

# %%
l1
# Out:
# ['abc', 'hello', 123, True, 100.191]

# %%
l1.insert(2, 'hello')

# %%
l1 # Mutable
# Out:
# ['abc', 'hello', 'hello', 123, True, 100.191]

# %%
# extend    # it works adding another list to existing list
l1.extend([1,2,3])

# %%
l1
# Out:
# ['abc', 'hello', 'hello', 123, True, 100.191, 1, 2, 3]

# %%
l1.count(3)
# Out:
# 1

# %% [markdown]
# ## Removing

# %%
# pop    # it removes the last element
l1
# Out:
# ['abc', 'hello', 'hello', 123, True, 100.191, 1, 2, 3]

# %%
l1.pop()
# Out:
# 3

# %%
l1.pop(2)
# Out:
# 'hello'

# %%
l1
# Out:
# ['abc', 'hello', 123, True, 100.191, 1, 2]

# %%
## remove # it works removing the elements
l1.remove(1)

# %%
l1
# Out:
# ['abc', 'hello', 123, 100.191, 1, 2]

# %%
## clear  # it removes all the elements but structure wont removed
l1.clear()

# %%
l1
# Out:
# []

# %%
l1 = [5,9,3,8,5]

# %%
l1
# Out:
# [5, 9, 3, 8, 5]

# %%
l1.sort() # ascending order

# %%
l1
# Out:
# [3, 5, 5, 8, 9]

# %%
l1.sort(reverse=True) # descending order

# %%
l1
# Out:
# [9, 8, 5, 5, 3]

# %%
# deleting
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %% [markdown]
# # Tuples

# %% [markdown]
# - Representation:()
# - Hetrogenous
# - Ordered and indexed
# - Immutable

# %% [markdown]
# - Tuple is similar to list, but we cannot change it.
# - Date of birth should not change.So we use Tuple

# %%
# Representation 
var1 = (1,2,3,4)
var1
# Out:
# (1, 2, 3, 4)

# %%
type(var1)
# Out:
# tuple

# %%
# Hetrogenous
var2 = ("hello",True,33,20.5)
var2
# Out:
# ('hello', True, 33, 20.5)

# %%
tup = ()
type(tup)
# Out:
# tuple

# %%
tup1=tuple()
type(tup1)
# Out:
# tuple

# %%
tup_1 = ('abc',21.11,False,100)
tup_1
# Out:
# ('abc', 21.11, False, 100)

# %%
tup` = (1,2) # we cannot give special characters to declare a variable
tup`
# Out:
#   Cell In[7], line 1
#     tup` = (1,2) # we cannot give special characters to declare a variable
#        ^
# SyntaxError: invalid syntax

# %%
## Nested tuple

# %%
tup2 = (1,2,3,4,(5,6,7,8),9)
tup2
# Out:
# (1, 2, 3, 4, (5, 6, 7, 8), 9)

# %%
# indexing
tup2[2]
# Out:
# 3

# %%
tup2[5]
# Out:
# 9

# %%
tup2[4]
# Out:
# (5, 6, 7, 8)

# %%
tup2[4][1]
# Out:
# 6

# %%
tup2[4][3]
# Out:
# 8

# %%
# negative indexing
tup2[-3]
# Out:
# 4

# %%
tup2[-5]
# Out:
# 2

# %%
tup2[-2]
# Out:
# (5, 6, 7, 8)

# %%
tup2[-2][-2]
# Out:
# 7

# %%
tup2 = (1,2,3,4,(5,6,7,8,),9)
tup2
# Out:
# (1, 2, 3, 4, (5, 6, 7, 8), 9)

# %%
# slicing
tup2[0:3]
# Out:
# (1, 2, 3)

# %%
tup2[4][1:3]
# Out:
# (6, 7)

# %%
tup2[3 :: 2]
# Out:
# (4, 9)

# %%
# negative slicing
tup2=[-2][-2: ]

# %% [markdown]
# # Tuple Functions

# %%
tup4 = (1,2,3,4,5,5,5,3,9,10)

# %%
len(tup4)
# Out:
# 10

# %%
tup4.count(5)
# Out:
# 3

# %%
tup4.index(3)
# Out:
# 2

# %%
tup4.index(5)
# Out:
# 4

# %%
sorted(tup4)
# Out:
# [1, 2, 3, 3, 4, 5, 5, 5, 9, 10]

# %%
sorted(tup4, reverse = True)
# Out:
# [10, 9, 5, 5, 5, 4, 3, 3, 2, 1]

# %%
tup4 # immutable
# Out:
# (1, 2, 3, 4, 5, 5, 5, 3, 9, 10)

# %%
del tup4

# %%
tup4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 tup4
#
# NameError: name 'tup4' is not defined
