# %% [markdown]
# # String slicing

# %%
str1 = "Hello Python"

# %%
str1[1:4] # start : stop but stop is exclusive
# Out:
# 'ell'

# %%
str1[0:8]
# Out:
# 'Hello Py'

# %%
str1[0:-8]
# Out:
# 'Hell'

# %%
str1[ :10]
# Out:
# 'Hello Pyth'

# %%
str1[0:15]
# Out:
# 'Hello Python'

# %%
str1[-5:]
# Out:
# 'ython'

# %%
str1[1:12:2] # step count
# Out:
# 'el yhn'

# %%
str1[1:12:3] # 3 is step count
# Out:
# 'eoyo'

# %%
str1[-8:-11] # This is decressing order so that we cant get the output
# Out:
# ''

# %%
str1[-11:-8] # we have to follow positive value
# Out:
# 'ell'

# %%
str1[::-1] # Reverse string
# Out:
# 'nohtyP olleH'

# %%
str1[::1]
# Out:
# 'Hello Python'

# %%
str1[-11:-2:2]
# Out:
# 'el yh'

# %%
str1[-11:-2:-2]
# Out:
# ''

# %%
str1[-2:-11:-2]
# Out:
# 'otPol'

# %%
str1[-2:-11:2]
# Out:
# ''

# %%
str1 # calling string
# Out:
# 'Hello Python'

# %%
# strings are immutable
str1[0:2] = "Hi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # strings are immutable
# ----> 2 str1[0:2] = "Hi"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# str1. # press tab button to select the options

# %%
str1.replace("He","Ke")
# Out:
# 'Kello Python'

# %%
str1
# Out:
# 'Hello Python'

# %% [markdown]
# # String concatination

# %%
s1 = "Hello"

# %%
s2 = "Python"

# %%
s3 = s1 +" " + s2

# %%
s3
# Out:
# 'Hello Python'

# %%
a="mohan"
b="kalyan"
c="sai"
d=a +" "+ b +" " + c
d
# Out:
# 'mohan kalyan sai'

# %%
a="mohan"
b="kalyan"
c="sai"
d=a+b+c
d
# Out:
# 'mohankalyansai'

# %% [markdown]
# # String membership

# %%
s3 = "Hello Python"

# %%
"He" in s3
# Out:
# True

# %%
"hee" in s3
# Out:
# False

# %%
"Python" in s3
# Out:
# True

# %%
"python" in s3 # because python is a case senstive language
# Out:
# False

# %%
"Py" not in s3
# Out:
# False

# %% [markdown]
# # String partitioning

# %% [markdown]
#  partition () searches for a substring as arjument to break up the string into 3 parts:
# - part before the argument
# - argument substring
# - part following the argument

# %%
str4 = "Natural language processing with python and R and Java"
L = str4.partition("and")
L
# Out:
# ('Natural language processing with python ', 'and', ' R and Java')

# %%
str4.count("and")  # by clicking and breses we can know more information
# Out:
# 2

# %% [markdown]
# # String Functions

# %%
# 1. Count

# %%
s1 ="Python Programming"
s1
# Out:
# 'Python Programming'

# %%
s1.

# %%
s1.count("P")
# Out:
# 2

# %%
s1.count("m")
# Out:
# 2

# %%
s1.count("a")
# Out:
# 1

# %%
s2 = " Hello Python "
s2
# Out:
# ' Hello Python '

# %%
s2.strip()
# Out:
# 'Hello Python'

# %%
# Lstrip()
s2.lstrip()
# Out:
# 'Hello Python '

# %%
# rstrip()
s2.rstrip()
# Out:
# ' Hello Python'

# %%
s5 = "****Hello*****Python****"
s5
# Out:
# '****Hello*****Python****'

# %%
s5.strip("*")
# Out:
# 'Hello*****Python'

# %%
s5 # Strings are immutable
# Out:
# '****Hello*****Python****'

# %%
s1 = "Python Programming"
s1.upper()
# Out:
# 'PYTHON PROGRAMMING'

# %%
s1.lower()
# Out:
# 'python programming'

# %%
# Startswith
s1
# Out:
# 'Python Programming'

# %%
s1.startswith("Py")
# Out:
# True

# %%
s1.startswith("py")
# Out:
# False

# %%
# endswith
s1
# Out:
# 'Python Programming'

# %%
s1.endswith("ig")
# Out:
# False

# %%
s1.endswith("ng")
# Out:
# True

# %% [markdown]
# # Formate() for a string
